# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import re
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../outputs/interventions.csv').query('speaker_name != "False"')
df_sessions = pd.read_csv('../outputs/sessions.csv', index_col=0)

# %%
num_words = df['intervention_text'].str.split().map(len).sum()
num_unique_words = pd.Series(' '.join(df['intervention_text']).split()).nunique()
print(f'Number of words in valid interventions: {num_words}')
print(f'Number of unique words in valid interventions: {num_unique_words}')
# Out:
# Number of words in valid interventions: 95627926
# Number of unique words in valid interventions: 981456

# %%
num_unique_speakers = df['speaker_name'].unique().shape[0]
n_valid_ints = df.query('speaker_name != "False"').shape[0]

print(f'Number of valid interventions: {n_valid_ints}')
print(f'Number of unique speakers: {num_unique_speakers}')
# Out:
# Number of valid interventions: 400052
# Number of unique speakers: 617

# %%
# df_sessions['date'] = pd.to_datetime(df_sessions['date'])
# range in time

# sessions per year

# %%
# example
